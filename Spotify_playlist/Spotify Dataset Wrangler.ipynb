# %% [markdown]
# # Generating Spotify Dataset

# %% [markdown]
# Spotify has a developer Web API that you can interact with to access the application's services. For this experiment, I marked 100 songs I disliked and 100 I liked to build a dataset that we are going to use for a Machine Learning experiment using Microsoft Azure. I used the Spotipy library for the development of this dataset.

# %% [markdown]
# ## Install Spotipy

# %%
pip install spotipy --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import relevant class

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# ## List Spotipy application Client ID and Client Secret

# %%
SPOTIPY_CLIENT_ID = '9XXXXXXXXXXXXXXXXXXXXXXX3' #Insert your specific client secret
SPOTIPY_CLIENT_SECRET = '7XXXXXXXXXXXXXXXXXXXXXXXXXd' #Insert your specific client secret

#Authenticate

auth_manager = SpotifyClientCredentials(SPOTIPY_CLIENT_ID,SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

disliked_urn = 'spotify:playlist:6Qy4uOBMCywLU5yE6FqzEu'
liked_urn= 'spotify:playlist:5muHYpeTUyLu6hbUtQBU44'

liked_playlist = sp.playlist(liked_urn)
disliked_playlist = sp.playlist_tracks(disliked_urn)

#print(playlist) Use to have overview of data structure and contents
#print(playlist.keys()) Use to view dictionary keys
#print(playlist.items()) Use to view dictionary items

# %%
#print(disliked_playlist['items']) to view values with 'items' key

#print (len(liked_playlist),len(disliked_playlist['items']))

#print(liked_playlist['tracks']['items'][0]['track']['id']) to view liked track ids
# Out:
# untitled 01 | 08.19.2014.

# %%
import pandas as pd
import json

disliked_track_list =[]
liked_track_list = []

disliked_tracks_string_list = []
liked_tracks_string_list = []

for i in range(len(disliked_playlist['items'])):
    
    disliked_track_list.append({"track":{"id":disliked_playlist['items'][i]['track']['id'],"name":disliked_playlist['items'][i]['track']['name']}})
    disliked_tracks_string_list.append(disliked_playlist['items'][i]['track']['id'])
    
for i in range(len(liked_playlist['tracks']['items'])):
    liked_track_list.append({"track":{"id":liked_playlist['tracks']['items'][i]['track']['id'],"name":liked_playlist['tracks']['items'][i]['track']['name']}})
    liked_tracks_string_list.append(liked_playlist['tracks']['items'][i]['track']['id'])

    #view entries by looking at type of data. details of track are stored in
    #

#print(dislike_ids['items'][0]['track']['id']) to view track id of first entry
#print(dislike_ids['items'][0]['track']['name']) to view artist name of first entry
# Out:
# ['6OkOFxU6j0UufR97VgSnS7', '3I0FBDc1c1BLNtXWKVjmFg', '2fgAJeky8Cpsr8Cfvn2NVp', '7a4hhCV3GlgA7a8wwJBy5B', '4M2t7bP4Mq87mGMn0PObUX', '40IQooNkPRVtn4zlE3ZFpA', '7uWVT3UkCAZyANvv0bdyQn', '4oFtLSgHyZPNYDCcANhTnO', '3ODXRUPL44f04cCacwiCLC', '3V8vWoCbKbfjNrPaQ4YtSg', '4tQcyj5488alHT1ZgFduzn', '3iVcZ5G6tvkXZkZKlMpIUs', '7lL3MvFWFFSD25pBz72Agj', '1WT11QmhZutciEv1NsHt1R', '4iYRa2btalAzPZoSYfROqF', '6HZILIRieu8S0iqY8kIKhj', '1bxEpNR75Hq3T2oF9AZjt8', '4txn9qnwK3ILQqv5oq2mO3', '23luOrEVHMfoX0AhfbQuS6', '06FCvd7rrRcF3DdvWH5Isp', '2LTlO3NuNVN70lp2ZbVswF', '1EaKU4dMbesXXd3BrLCtYG', '6IZvVAP7VPPnsGX6bvgkqg', '6SwRhMLwNqEi6alNPVG00n', '6PGoSes0D9eUDeeAafB2As', '2q0VexHJirnUPnEOhr2DxK', '53mCo1wDJ12iZNq9LgIeg2', '6NyhBA9M6KK0fuVsojxL00', '0ECs7wpW9157Tk5yBUGbE0', '2lD6AoA8qf2t4Dkf2TcmNK', '3rFF7kSm5qBOOPs6ljFgPp', '6onwlDmIVKE8bBgyBRSuS0', '5Lgqu1th1KqlG97OF2gWGe', '0Px86mRlxdB3YqpK6KXWlr', '6tZ3b7ik1QDXFAZlXib0YZ', '7zFXmv6vqI4qOt4yGf3jYZ', '1Mza2sr6tPhy6jjI3HB9fW', '59acp1OhcvxwVBwQJBYKuX', '0KyzXQhY
# ...

# %%
# Out:
# 0  6OkOFxU6j0UufR97VgSnS7
#
# 1  3I0FBDc1c1BLNtXWKVjmFg
#
# 2  2fgAJeky8Cpsr8Cfvn2NVp
#
# 3  7a4hhCV3GlgA7a8wwJBy5B
#
# 4  4M2t7bP4Mq87mGMn0PObUX
#
# 5  40IQooNkPRVtn4zlE3ZFpA
#
# 6  7uWVT3UkCAZyANvv0bdyQn
#
# 7  4oFtLSgHyZPNYDCcANhTnO
#
# 8  3ODXRUPL44f04cCacwiCLC
#
# 9  3V8vWoCbKbfjNrPaQ4YtSg
#
# 10  4tQcyj5488alHT1ZgFduzn
#
# 11  3iVcZ5G6tvkXZkZKlMpIUs
#
# 12  7lL3MvFWFFSD25pBz72Agj
#
# 13  1WT11QmhZutciEv1NsHt1R
#
# 14  4iYRa2btalAzPZoSYfROqF
#
# 15  6HZILIRieu8S0iqY8kIKhj
#
# 16  1bxEpNR75Hq3T2oF9AZjt8
#
# 17  4txn9qnwK3ILQqv5oq2mO3
#
# 18  23luOrEVHMfoX0AhfbQuS6
#
# 19  06FCvd7rrRcF3DdvWH5Isp
#
# 20  2LTlO3NuNVN70lp2ZbVswF
#
# 21  1EaKU4dMbesXXd3BrLCtYG
#
# 22  6IZvVAP7VPPnsGX6bvgkqg
#
# 23  6SwRhMLwNqEi6alNPVG00n
#
# 24  6PGoSes0D9eUDeeAafB2As
#
# 25  2q0VexHJirnUPnEOhr2DxK
#
# 26  53mCo1wDJ12iZNq9LgIeg2
#
# 27  6NyhBA9M6KK0fuVsojxL00
#
# 28  0ECs7wpW9157Tk5yBUGbE0
#
# 29  2lD6AoA8qf2t4Dkf2TcmNK
#
# 30  3rFF7kSm5qBOOPs6ljFgPp
#
# 31  6onwlDmIVKE8bBgyBRSuS0
#
# ...

# %%
import requests
import pandas as pd

headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': 'Bearer BQBoqE45jbqwbDrhCbqt2E3lCAzMMKnPxMMMuKxRk_DFCx3z2O2bTt8qyJ-j-FB-uqQuEEWpBH3xqgi_lAQkA_ebo1o1pIixfY4XeEQIHfRW-QWqZr1wjl3Bd7p09dP_hIdbuSDxarDtyBoF1puj_T-9hSWSa9of4t1Isq91dLDxmlFKElDgU2VPhHQ',

}


#column_names = 
#
#params = (('ids', track_ids),)

#response = requests.get('https://api.spotify.com/v1/audio-features', headers=headers, params=params)
 #   json_instance = response.json()
  #  track_list_entry=json_instance['audio_features']

liked_tracks_df_features=pd.DataFrame(columns=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])

for track_ids in liked_tracks_string_list:
    params = (('ids', track_ids),)

    response = requests.get('https://api.spotify.com/v1/audio-features', headers=headers, params=params)
    json_instance = response.json()
    track_list_entry=json_instance['audio_features']
    ##json_instance datatype is a dict with audio_features as the primary key
    ##to access audio_features, use json_instance['audio_features']
    
    ##transform the dictionary to a dataframe for simplicity
    liked_track_df_instance = pd.DataFrame.from_dict(json_instance['audio_features'])
    liked_tracks_df_features=liked_tracks_df_features.append(liked_track_df_instance)


    ##text_instance = response.text to observe string (json format) from API
    ##json_instance = response.json() to observe json output from API

# %%
#To display all tracks with categorical features call liked_tracks_df_features

# %%
#Add another column to display that track was liked

liked_tracks_df_features['liked']=1

# call liked_tracks_df_features to check accuracy

# %%
liked_tracks_df_features=liked_tracks_df_features.iloc[:][['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo','liked']]

liked_tracks_df_features
# Out:
#     danceability  energy key  loudness mode  speechiness  acousticness  \
# 0          0.570   0.584   2   -11.708    1       0.4050        0.3210
# 0          0.667   0.508   5   -10.337    1       0.4510        0.3410
# 0          0.813   0.549   5   -12.427    0       0.2690        0.6080
# 0          0.541   0.490   5    -6.112    0       0.0897        0.0992
# 0          0.669   0.541   4   -11.291    0       0.0461        0.0992
# ..           ...     ...  ..       ...  ...          ...           ...
# 0          0.544   0.552   9    -7.450    1       0.0991        0.6700
# 0          0.559   0.578   8    -9.540    1       0.1510        0.7900
# 0          0.447   0.422   1   -11.076    0       0.1670        0.8720
# 0          0.552   0.731   7    -6.873    1       0.6150        0.0536
# 0          0.357   0.238   8   -16.780    0       0.2650        0.1420
#
#    instrumentalness  liveness  valence    tempo  liked
# 0                 0    0.0868    0.107  102.190      1
# ...

# %%
#Creating a dataframe for the disliked tracks with above steps repeated

disliked_tracks_df_features=pd.DataFrame(columns=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])

for track_ids in disliked_tracks_string_list:
    params = (('ids', track_ids),)

    response = requests.get('https://api.spotify.com/v1/audio-features', headers=headers, params=params)
    json_instance = response.json()
    track_list_entry=json_instance['audio_features']
    ##json_instance datatype is a dict with audio_features as the primary key
    ##to access audio_features, use json_instance['audio_features']
    
    ##transform the dictionary to a dataframe for simplicity
    disliked_track_df_instance = pd.DataFrame.from_dict(json_instance['audio_features'])
    disliked_tracks_df_features= disliked_tracks_df_features.append(disliked_track_df_instance)
    
    #Add another column to display that track was disliked
disliked_tracks_df_features['liked']=0

# %%
disliked_tracks_df_features=disliked_tracks_df_features.iloc[:][['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo','liked']]    

disliked_tracks_df_features
# Out:
#     danceability  energy key  loudness mode  speechiness  acousticness  \
# 0          0.538   0.512   4    -4.548    0       0.0262       0.22000
# 0          0.413   0.640   8    -5.811    1       0.0427       0.27300
# 0          0.789   0.742  10    -5.664    0       0.0652       0.06810
# 0          0.790   0.714   1    -7.860    0       0.2020       0.00142
# 0          0.901   0.715  11    -4.960    1       0.2590       0.17300
# ..           ...     ...  ..       ...  ...          ...           ...
# 0          0.849   0.719  10    -2.552    0       0.1680       0.38800
# 0          0.763   0.541   1    -8.979    1       0.0675       0.26400
# 0          0.782   0.686   7   -16.893    1       0.2870       0.05760
# 0          0.819   0.531   7    -8.830    1       0.2480       0.51800
# 0          0.615   0.714   7    -8.664    1       0.0636       0.25000
#
#    instrumentalness  liveness  valence    tempo  liked
# 0                 0    0.1010   0.1200  144.978      0
# ...

# %%
merged_tracks=merged_tracks.iloc[:][['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo','liked']]

merged_tracks=disliked_tracks_df_features.append(liked_tracks_df_features)

merged_tracks
# Out:
#     danceability  energy key  loudness mode  speechiness  acousticness  \
# 0          0.538   0.512   4    -4.548    0       0.0262       0.22000
# 0          0.413   0.640   8    -5.811    1       0.0427       0.27300
# 0          0.789   0.742  10    -5.664    0       0.0652       0.06810
# 0          0.790   0.714   1    -7.860    0       0.2020       0.00142
# 0          0.901   0.715  11    -4.960    1       0.2590       0.17300
# ..           ...     ...  ..       ...  ...          ...           ...
# 0          0.544   0.552   9    -7.450    1       0.0991       0.67000
# 0          0.559   0.578   8    -9.540    1       0.1510       0.79000
# 0          0.447   0.422   1   -11.076    0       0.1670       0.87200
# 0          0.552   0.731   7    -6.873    1       0.6150       0.05360
# 0          0.357   0.238   8   -16.780    0       0.2650       0.14200
#
#    instrumentalness  liveness  valence    tempo  liked
# 0                 0     0.101    0.120  144.978      0
# ...

# %%
#shuffle the entries

merged_tracks=merged_tracks.sample(frac=1)

# %%
#Covnert the dataframe to a csv

merged_tracks.to_csv('/home/mufumi/Desktop/Spotify_playlist/spotify_playlist.csv', header =['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo','liked'], index=False)
